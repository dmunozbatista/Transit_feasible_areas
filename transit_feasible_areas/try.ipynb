# %%
from backend import get_relevant_stops as st

lat = 41.781729
lon = -87.60491761427323

st.relevant_stops(lat, lon, 0.3)
# Out:
#                                         name        lat        lon  type
# 0                Cottage Grove Ave & 63rd St  41.780531 -87.605970  bike
# 1                       Drexel Ave & 60th St  41.785861 -87.604553  bike
# 2          Public Rack - Evans Ave & 63rd St  41.780506 -87.607519  bike
# 3   63rd Street & Cottage Grove (Green Line)  41.780465 -87.606174   bus
# 4                        63rd Street & Ellis  41.780526 -87.601288   bus
# 5                Cottage Grove & 60th Street  41.785789 -87.606169   bus
# 6                Cottage Grove & 64th Street  41.778344 -87.605993   bus
# 7                Cottage Grove & 62nd Street  41.782383 -87.606062   bus
# 8                    63rd Street & Ingleside  41.780370 -87.602558   bus
# 9                Cottage Grove & 61st Street  41.784137 -87.606130   bus
# 10                       915 E. 60th Street   41.785864 -87.603831   bus
# 11                      63rd Street & Drexel  41.780376 -87.604292   bus
# ...
